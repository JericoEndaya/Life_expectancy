# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.interpolate import griddata
import plotly.express as px
import missingno as msno
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import dendrogram, linkage
from fancyimpute import IterativeImputer as mice
# Out:
# (CVXPY) Oct 04 05:40:51 PM: Encountered unexpected exception importing solver OSQP:
# ImportError('DLL load failed while importing qdldl: The specified module could not be found.')

# %%
df = pd.read_csv('life expectancy.csv')
df.head()
# Out:
#            Country Name Country Code                      Region  \
# 0           Afghanistan          AFG                  South Asia
# 1                Angola          AGO          Sub-Saharan Africa
# 2               Albania          ALB       Europe & Central Asia
# 3               Andorra          AND       Europe & Central Asia
# 4  United Arab Emirates          ARE  Middle East & North Africa
#
#            IncomeGroup  Year  Life Expectancy World Bank  \
# 0           Low income  2001                      56.308
# 1  Lower middle income  2001                      47.059
# 2  Upper middle income  2001                      74.288
# 3          High income  2001                         NaN
# 4          High income  2001                      74.544
#
#    Prevelance of Undernourishment      CO2  Health Expenditure %  \
# 0                            47.8    730.0                   NaN
# 1                            67.5  15960.0              4.483516
# ...

# %%
df.describe()
# Out:
#               Year  Life Expectancy World Bank  \
# count  3306.000000                 3118.000000
# mean   2010.000000                   69.748362
# std       5.478054                    9.408154
# min    2001.000000                   40.369000
# 25%    2005.000000                   63.642000
# 50%    2010.000000                   72.168500
# 75%    2015.000000                   76.809000
# max    2019.000000                   84.356341
#
#        Prevelance of Undernourishment           CO2  Health Expenditure %  \
# count                     2622.000000  3.154000e+03           3126.000000
# mean                        10.663654  1.574924e+05              6.364059
# std                         11.285897  7.726415e+05              2.842844
# min                          2.500000  1.000000e+01              1.263576
# 25%                          2.500000  2.002500e+03              4.205443
# 50%                          6.200000  1.020500e+04              5.892352
# ...

# %% [markdown]
# ### Identifying and treating missing data

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
only_missing = percent_missing.sort_values(ascending=False) 
only_missing = only_missing[only_missing >0]
only_missing
# Out:
# Corruption                        70.508167
# Sanitation                        37.719298
# Education Expenditure %           32.970357
# Prevelance of Undernourishment    20.689655
# Unemployment                       9.195402
# Life Expectancy World Bank         5.686630
# Health Expenditure %               5.444646
# CO2                                4.597701
# dtype: float64

# %% [markdown]
# A large portion of 'Corruption' seems to be missing followed by 'Sanitaion', 'Education expenditure', and 'Prevalence of Under Nourishment'.

# %%
msno.bar(df, figsize=(8, 6), fontsize=8)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here is the missing data visualized

# %%
msno.heatmap(df, figsize=(8, 6), fontsize=8)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Above is a correlation heat map of missing data. Here we can see that unemployment and life expectancy has a value of 0.8 which means that if life expectancy has a value, there is an 80% chance that unemployment will have a missing value and vice versa.
#
# Similar case with CO2 and health expenditure, if CO2 has a value, there is a 70% chance that health expenditure will a missing value and vice versa.
#
# I conclude that the cause of missing data is higly likely to be within the dataset itself which makes the nature of the missing data to be Missing At Random (MAR). Therefore, I elected to use MICE imputation in order to fill in the missing data as I believe its provides a more robust and complete dataset as opposed to simpler but efficient methods such as mean imputation.

# %%
#store the dropped columns for later
country_name = df['Country Name']
country_code = df['Country Code']
region = df['Region']
income_group = df['IncomeGroup']

#impute the missing data from remaining columns
df_nocat = df.drop(['Country Name','Country Code', 'Region', 'IncomeGroup'], axis=1)
df_imp = mice().fit_transform(df_nocat)

# Convert the result back to DataFrame
df_imp = pd.DataFrame(df_imp, columns = df_nocat.columns)

# Add the dropped columns back to the DataFrame
df_imp['Country Name'] = country_name.values
df_imp['Country Code'] = country_code.values
df_imp['Region'] = region.values
df_imp['IncomeGroup'] = income_group.values

# %% [markdown]
# ### Outlier Identification and Treatment

# %%
columns = ['Life Expectancy World Bank', 'Prevelance of Undernourishment', 'CO2', 'Health Expenditure %',
           'Education Expenditure %','Unemployment','Corruption','Sanitation','Injuries','Communicable','NonCommunicable']
n_cols = 4
n_rows = 3

# Initialize subplot index
subplot_index = 1

# Create the figure
plt.figure(figsize=(12, 12))

# for each column in columns, make a boxplot
for column in columns:
    plt.subplot(n_rows, n_cols, subplot_index)
    plt.boxplot(df_imp[column])
    plt.title(f'{column}')
    
    # Increment subplot index for the next loop iteration
    subplot_index += 1

# Show the plot
plt.subplots_adjust(wspace=2) 
plt.show()

# %% [markdown]
# Aside from "Sanitation", I can see through visual inspection that there is presence of outliers for each variable.

# %%
columns = ['Life Expectancy World Bank', 'Prevelance of Undernourishment', 'CO2', 'Health Expenditure %',
           'Education Expenditure %','Unemployment','Corruption','Sanitation','Injuries','Communicable','NonCommunicable']
n_cols = 3
n_rows = 4

# Initialize subplot index
subplot_index = 1

# Create the figure
plt.figure(figsize=(30, 30))

# for each column in columns, make a boxplot
for column in columns:
    plt.subplot(n_rows, n_cols, subplot_index)
    sns.histplot(df_imp[column],bins = 100)
    plt.title(f'{column}')
    
    # Increment subplot index for the next loop iteration
    subplot_index += 1

# Show the plot
plt.subplots_adjust(wspace=0.1) 
plt.show()

# %% [markdown]
# The outliers previously mentioned are further highlighted when the distributions are visualized. The standard approach would be to treat the outliers in some way to remove or reduce their influence on the analysis, however, this is data based on socio-economic factors therefore some countries would have vastly different circumstances.
#
# An example would be the prevalence of under nourishment, in an ideal situation, all countries would be close to zero yet there some countries that suffer malnutrition due to poor infrastructure and capital. The same can be said for life expectancy where on average a person should be living at least until 70 but poor socieconomic factors lower this factor depending on the country.
#
# The course of action for this observation would be to leave the outliers as they are, it would arguably be less accurate to treat the outliers as it is unlikely to be explained simply  through human error.

# %% [markdown]
# ### Categorical Variables Analysis

# %%
#Country name Bar plot
regions = df_imp.groupby(['Region'])['Country Name'].size().sort_values(ascending=False)

# Plot the bar chart
plt.figure(figsize=(8, 4))
sns.barplot(x = regions.index, y = regions.values)
plt.xlabel("Region")
plt.ylabel("Number of Countries")
plt.title("Region Distribution")
plt.xticks(rotation=45)
plt.show()

# %%
region_class = df_imp.groupby(['Region','IncomeGroup']).size()
region_class
# Out:
# Region                      IncomeGroup
# East Asia & Pacific         High income            133
#                             Lower middle income    209
#                             Upper middle income    171
# Europe & Central Asia       High income            589
#                             Lower middle income     57
#                             Upper middle income    247
# Latin America & Caribbean   High income            133
#                             Lower middle income     95
#                             Upper middle income    323
# Middle East & North Africa  High income            152
#                             Lower middle income     95
#                             Upper middle income     57
# North America               High income             57
# South Asia                  Low income              19
#                             Lower middle income    114
#                             Upper middle income     19
# ...

# %%
region = df_imp[['Region','IncomeGroup','Year']]
region_c = region.pivot_table(index='Region', columns='IncomeGroup', aggfunc='size', fill_value=0)

# Initialize the matplotlib figure
fig, ax = plt.subplots(figsize=(10, 6))

# Create the bar plots
ax.barh(region_c.index, region_c['Low income'], label='Low income', color='red')
ax.barh(region_c.index, region_c['Lower middle income'], left=region_c['Low income'], label='Lower middle income', color='orange')
ax.barh(region_c.index, region_c['Upper middle income'], left=region_c['Low income'] + region_c['Lower middle income'], label='Upper middle income', color='yellow')
ax.barh(region_c.index, region_c['High income'], left=region_c['Low income'] + region_c['Lower middle income'] + region_c['Upper middle income'], label='High income', color='green')

# Add a legend and informative axis label
ax.legend(loc='lower right')
ax.set_xlabel('Income class per Region')

# Show plot
plt.show()

# %% [markdown]
# Above is a bar graph detailing the proportion of Income classes per region. Sub-Saharan Africa seems to have the low income class as most prevalent while Europe & Central Asia are doing well with the highest proportion of High income.

# %% [markdown]
# line graph comparing yearly life expecntacies of each country

# %%
region_life = df_imp[['Region','Life Expectancy World Bank','Year']]
lifexp_year = region_life.groupby(['Region','Year']).agg({
    'Life Expectancy World Bank': 'mean',
}).reset_index()
lifexp_year = lifexp_year.sort_values('Year', ascending=True)

plt.figure(figsize=(8, 6))
sns.lineplot(x='Year', y='Life Expectancy World Bank', hue='Region', data=lifexp_year)
plt.grid(True, linestyle='--', linewidth=0.5, color='gray')
plt.title('Life Expectancy per Year by Region')
plt.xlabel('Year')
plt.ylabel('Life Expectancy')
plt.legend(title='Region')
plt.xticks([int(tick) for tick in plt.xticks()[0] if tick.is_integer()])

plt.show()

# %% [markdown]
# Complimenting the information derived from the income groups, North America seems to have the highest life expectancy  while sub-saharan africa has the lowest, fortunately, all seem to have an increasing trend. With sub-saharan having the most countries within the low-income group, it makes sense that it also has the lowest life expectancy, the genreal populace simply does not have the infrastructure nore the income to support a healthy lifestyle.

# %% [markdown]
# ### Numerical variable analysis

# %%
correlation_matrix = df_imp[['Life Expectancy World Bank', 'Prevelance of Undernourishment', 'CO2', 'Health Expenditure %',
           'Education Expenditure %','Unemployment','Corruption','Sanitation','Injuries','Communicable','NonCommunicable']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# According to the correlation matrix, there are several factors that exhibit high correlations:
#
# life expectancy/sanitation=0.75, life expectancy/undernourishment=-0.73, undernourishment/sanitation=-0.6, CO2/nonCommunicable=0.82, CO2/injuries=0.65, injuries/nonCommunicable=0.95, injuries/Communicable=0.77, communicable/nonCommunicable=0.62.
#
# Here we can see that higher levels of sanitation is positively correlated with life expectancy while the presence of undernourishment seems to have a negative correlation with life expectancy. Sanitation helps in preventing disease while undernourishment leads to weaker immune systems.
#
# CO2 levels have a high positive correlation with Disability-Adjusted Life Years (DALYs) due to Non-Communicable diseases which means that for every unit increase of C02, there is a correlated increase in one year loss of a healthy life. Same case with injuries although at a lower degree.
#
# Injuries also have a high positive correlation with both nonCommunicable and Communicable, in other words, the presence of injuries is likely to also have presence of a year loss of a healthy life either through communicable or noncommunicable diseases.
#
# I will take a closer look at these variables.

# %% [markdown]
# #### How has Undernourishment changed over time?

# %%
region_under = df_imp[['Region','Prevelance of Undernourishment','Year']]
under_year = region_under.groupby(['Region','Year']).agg({
    'Prevelance of Undernourishment': 'mean',
}).reset_index()
under_year = under_year.sort_values('Year', ascending=True)

plt.figure(figsize=(8, 6))
sns.lineplot(x='Year', y='Prevelance of Undernourishment', hue='Region', data=under_year)
plt.grid(True, linestyle='--', linewidth=0.5, color='gray')
plt.title('Prevelance of Undernourishment per Year by Region')
plt.xlabel('Year')
plt.ylabel('Prevalence of Undernourishment')
plt.legend(title='Region')
plt.xticks([int(tick) for tick in plt.xticks()[0] if tick.is_integer()])

plt.show()

# %% [markdown]
# Although every region seems to have their rate of undernourishment on a downward trend, Sub-Saharan Africa still seems to have over 20% on average which is well over double the next highest rate at just 10% from Middle East & North Africa. North America has the lowest rates of Undernourishment which is higly likely due to being economically well off relative to every other region.

# %% [markdown]
# #### Sanitation and Undernourishment

# %%
plt.figure(figsize=(8, 6))
plt.scatter(x='Sanitation', y='Prevelance of Undernourishment', data=df_imp, alpha=0.5)
plt.title("World Sanitation/Undernourishment Scatter plot")
plt.xlabel("Sanitation Levels")
plt.ylabel("Undernourishment")
plt.show()

# %% [markdown]
# The scattrerplot above visualizes the previously determined negative correlation between Sanitation levels and Undernourishment. As we can see, higher levels of sanitation leads to lower rates of undernourishment. This is likely because a country with high rates of sanitaion can afford to have a higher standard of living and therefore less likely to have its citizens undernourished.

# %% [markdown]
# ### Clustering

# %% [markdown]
# Perhaps its possible that we can group the countries together alternative to just their region, I will attempt to do some cluster analysis in order to see what types of groups there are available and what set of variables do they share.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer

# Identify numerical and categorical columns
numerical_cols = df_imp.select_dtypes(include=['float64', 'int64']).columns
categorical_cols = df_imp.select_dtypes(include=['object']).columns

# Frequency encoding for categorical columns
for col in categorical_cols:
    freq_encoding = df_imp[col].value_counts(normalize=True)
    df_imp[col] = df_imp[col].map(freq_encoding)

# Create preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_cols),
        ('cat', 'passthrough', categorical_cols)])

# Apply preprocessing
df_preprocessed = preprocessor.fit_transform(df_imp)

# Run K-means
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, n_init=10, random_state=42)
    kmeans.fit(df_preprocessed)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# Using the elbow method, I have determined the number of cluster to be three, countries would be grouped into three based on the similarity of their features

# %%
kmeans_final = KMeans(n_clusters=3,n_init=10, random_state=42)
kmeans_final.fit(df_imp)
df_imp['Cluster'] = kmeans_final.labels_

cluster_summary = df_imp.groupby('Cluster').mean()
cluster_summary
# Out:
#            Year  Life Expectancy World Bank  Prevelance of Undernourishment  \
# Cluster
# 0        2010.0                   69.900997                       11.128676
# 1        2010.0                   74.417368                        4.515789
# 2        2010.0                   66.533526                       16.794737
#
#                   CO2  Health Expenditure %  Education Expenditure %  \
# Cluster
# 0        9.750845e+04              6.405639                 4.580642
# 1        7.862438e+06              4.501540                 3.614286
# 2        1.670617e+06              3.559528                 3.661387
#
#          Unemployment  Corruption  Sanitation      Injuries  Communicable  \
# Cluster
# 0            8.027123    3.000304   48.313595  7.849097e+05  3.355791e+06
# 1            4.472105    1.469398   37.187109  4.130631e+07  3.052914e+07
# 2            5.483368    3.244365   25.506500  5.305942e+07  2.076890e+08
#
# ...

# %%
columns = ['Life Expectancy World Bank', 'Prevelance of Undernourishment', 'CO2', 'Health Expenditure %',
           'Education Expenditure %','Unemployment','Corruption','Sanitation','Injuries','Communicable','NonCommunicable']
n_cols = 3
n_rows = 4

# Initialize subplot index
subplot_index = 1

# Create the figure
plt.figure(figsize=(30, 30))

# for each column in columns, make a boxplot
for column in columns:
    plt.subplot(n_rows, n_cols, subplot_index)
    sns.boxplot(x='Cluster', y=column, data=df_imp)
    plt.title(f'{column}')
    
    # Increment subplot index for the next loop iteration
    subplot_index += 1

# Show the plot
plt.subplots_adjust(wspace=0.1) 
plt.show()

# %% [markdown]
# Using K-means clustering, I was able to determine three clusters. I will explain their features:
#
# Cluster 0 (Developed): highest average life expectancy, medium rate of undernoursihment, lowest CO2 levels, highest average health expenditure, highest average level education expenditure, highest level average rate of unemployment, medium rate of corruption, highest average sanitation, lowest rate of injuries, lowest average communicable disease and lowest average Non-communicable disease
#
# Cluster 1 (Semi-developed): medium average life expectancy, lowest rate of undernoursihment, highest CO2 levels, medium health expenditure, medium level education expenditure, lowest rate of unemployment, lowest rate of corruption, highest average sanitation, lowest rate of injuries, lowest average communicable disease and lowest average Non-communicable disease

# %% [markdown]
# |  | Developed  | semi | under  |
# |-----------|-----------|-----------|-----------|
# | life expectancy | highest  | Cell 1,3  | Cell 1,4  |
# | Undernourishment  | Cell 2,2  | Cell 2,3  | Cell 2,4  |
# | CO2  | Cell 3,2  | Cell 3,3  | Cell 3,4  |
# | % Health expenditure  | Cell 4,2  | Cell 4,3  | Cell 4,4  |
# | % Education expenditure | Cell 5,2  | Cell 5,3  | Cell 5,4  |
# | % Unemployment  | Cell 6,2  | Cell 6,3  | Cell 6,4  |
# | % Corruption  | Cell 7,2  | Cell 7,3  | Cell 7,4  |
# | % Sanitation  | Cell 8,2  | Cell 8,3  | Cell 8,4  |
# | % Injuries  | Cell 9,2  | Cell 9,3  | Cell 9,4  |
# | % Communicable Diseases | Cell 10,2 | Cell 10,3 | Cell 10,4 |
# | % Non-Communicable Diseases | Cell 11,2 | Cell 11,3 | Cell 11,4 |
